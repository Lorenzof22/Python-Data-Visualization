# %% [markdown]
# # Data

# %% [markdown]
# The location data extracted below will be used for the analysis. Foursquare data provides all nearby venues within a neighborhood. For this paper we will only keep the sports and recreational venues when we conduct our analysis. Cluster analysis will be used to group each neighborhood according to available sports and recreational venues.

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped
# Out:
#                                           Neighborhood  Accessories Store  \
# 0                                            Agincourt              0.000
# 1                               Alderwood, Long Branch              0.000
# 2      Bathurst Manor, Wilson Heights, Downsview North              0.000
# 3                                      Bayview Village              0.000
# 4                    Bedford Park, Lawrence Manor East              0.000
# 5                                          Berczy Park              0.000
# 6                          Birch Cliff, Cliffside West              0.000
# 7         Brockton, Parkdale Village, Exhibition Place              0.000
# 8    CN Tower, King and Spadina, Railway Lands, Har...              0.000
# 9                                  Caledonia-Fairbanks              0.000
# 10                                           Cedarbrae              0.000
# 11                                  Central Bay Street              0.000
# ...

# %%
toronto_grouped.shape
# Out:
# (101, 269)
